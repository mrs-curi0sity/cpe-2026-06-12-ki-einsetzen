# %%
# !pip install --upgrade pip
# !pip install plotly
# Out:
# Requirement already satisfied: pip in ./venv/lib/python3.13/site-packages (25.2)
# Collecting pip
#   Downloading pip-26.1.2-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.1.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 8.2 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.2
#     Uninstalling pip-25.2:
#       Successfully uninstalled pip-25.2
# Successfully installed pip-26.1.2
# Requirement already satisfied: plotly in ./venv/lib/python3.13/site-packages (6.8.0)
# Requirement already satisfied: narwhals>=1.15.1 in ./venv/lib/python3.13/site-packages (from plotly) (2.22.1)
# Requirement already satisfied: packaging in ./venv/lib/python3.13/site-packages (from plotly) (26.2)

# %%
import plotly.io as pio
import plotly.graph_objects as go
pio.renderers.default = "iframe"
#pio.renderers.default = "notebook"  # oder "iframe"
#pio.renderers.default = "plotly_mimetype+notebook"

pio.templates["quarto"] = go.layout.Template(
    layout=dict(
        font=dict(size=11),  # Standard ist 12, hier z.B. 11
        autosize=True,
        legend=dict(
            orientation="h",
            yanchor="bottom",
            y=-0.25,
            xanchor="center",
            x=0.5
        )
    )
)

pio.templates.default = "quarto"

# %%
def img_to_base64(img_path):
    with open(img_path, 'rb') as f:
        encoded = base64.b64encode(f.read()).decode('utf-8')
    return f'data:image/png;base64,{encoded}'

# %% [markdown]
# ---
# title: "Basiswissen KI"
# author: "Lena Aretz"
# execute:
#   echo: false
# format:
#   revealjs:
#     footer: "Lena Aretz | 11.03.2026"
#     slide-number: true
#     logo: "./images/ukb_logo.png"
#     toc: false
#     toc-title: "Inhalt"
#     include-in-header:
#       text: |
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#         <style>
#         .reveal .slide-logo {
#           max-height: 70px !important;
#           right: 12px !important;
#           bottom: 12px !important;
#         }
#         </style>
#   html:
#     toc: true
#     toc-title: "Inhalt"
#     self-contained: true
#   pdf:
#     toc: true
#     toc-title: "Inhalt"
#
# ---

# %% [markdown]
# ![](./images/Lena_Profil_06.png)

# %% [markdown]
# ## Ablaufplan Vormittag
# | Zeit | Inhalt |
# |---|---|
# | 09:00 | Warm-up: Vorstellung + Erwartungen ans Whiteboard |
# | 09:20 | Vortrag Teil I: Was ist KI? Was kann sie? |
# | 09:50 | Brainstorming 1: Welche Probleme habt ihr? → Post-its clustern |
# | 10:30 | ☕ Pause |
# | 10:45 | Vortrag Teil II: KI-Level: trainieren / finetunen / API |
# | 11:15 | Brainstorming 2: Welches Level passt zu eurem Problem? |
# | 12:00 | 🍽️ Mittagspause |

# %% [markdown]
# ## Ablaufplan Nachmittag
# | Zeit | Inhalt |
# |---|---|
# | 13:00 | Ihr pitcht eure Use Cases → gemeinsame Einschätzung live |
# | 15:00 | ☕ Pause |
# | 15:15 | Vortrag C: Ausblick: RAG, Agents, Sensorik, Zukunft |
# | 16:00 | Roadmaps: 1-Pager Problem → Methode → nächster Schritt |
# | 16:45 | Abschluss: Feedback, offene Fragen, Zusammenarbeit |
